# %%
import numpy as np

# %%
dado = np.loadtxt('apples_ts.csv', delimiter=',',usecols=np.arange(1,88,1))

# %%
dado
# Out:
# array([[  1.2013,   2.2013,   3.2013,   4.2013,   5.2013,   6.2013,
#           7.2013,   8.2013,   9.2013,  10.2013,  11.2013,  12.2013,
#           1.2014,   2.2014,   3.2014,   4.2014,   5.2014,   6.2014,
#           7.2014,   8.2014,   9.2014,  10.2014,  11.2014,  12.2014,
#           1.2015,   2.2015,   3.2015,   4.2015,   5.2015,   6.2015,
#           7.2015,   8.2015,   9.2015,  10.2015,  11.2015,  12.2015,
#           1.2016,   2.2016,   3.2016,   4.2016,   5.2016,   6.2016,
#           7.2016,   8.2016,   9.2016,  10.2016,  11.2016,  12.2016,
#           1.2017,   2.2017,   3.2017,   4.2017,   5.2017,   6.2017,
#           7.2017,   8.2017,   9.2017,  10.2017,  11.2017,  12.2017,
#           1.2018,   2.2018,   3.2018,   4.2018,   5.2018,   6.2018,
#           7.2018,   8.2018,   9.2018,  10.2018,  11.2018,  12.2018,
#           1.2019,   2.2019,   3.2019,   4.2019,   5.2019,   6.2019,
#           7.2019,   8.2019,   9.2019,  10.2019,  11.2019,  12.2019,
# ...

# %%
dado.ndim
# Out:
# 2

# %%
dado.size
# Out:
# 522

# %%
dado.shape
# Out:
# (6, 87)

# %%
dado_transposto= dado.T

# %% [markdown]
# # Desafio 1

# %%
url = 'https://raw.githubusercontent.com/allanspadini/numpy/dados/citrus.csv'

# %%
np.loadtxt(url, delimiter=',',skiprows=1, usecols=np.arange(1,6,1))
# Out:
# array([[  2.96,  86.76, 172.  ,  85.  ,   2.  ],
#        [  3.91,  88.05, 166.  ,  78.  ,   3.  ],
#        [  4.42,  95.17, 156.  ,  81.  ,   2.  ],
#        ...,
#        [ 15.59, 256.5 , 168.  ,  82.  ,  20.  ],
#        [ 15.92, 260.14, 142.  ,  72.  ,  11.  ],
#        [ 16.45, 261.51, 152.  ,  74.  ,   2.  ]])

# %% [markdown]
# # ----------------------------

# %%
dado_transposto
# Out:
# array([[  1.2013,  79.72  ,  42.67  ,  62.55  ,  48.26  ,  71.25  ],
#        [  2.2013,  81.08  ,  44.37  ,  62.73  ,  51.01  ,  71.35  ],
#        [  3.2013,  79.68  ,  44.73  ,  63.43  ,  50.91  ,  70.9   ],
#        [  4.2013,  79.8   ,  46.75  ,  63.83  ,  53.94  ,  71.92  ],
#        [  5.2013,  80.63  ,      nan,  66.06  ,  61.27  ,  72.91  ],
#        [  6.2013,  80.8   ,  51.59  ,  69.22  ,  65.44  ,  74.39  ],
#        [  7.2013,  80.28  ,  57.8   ,  72.07  ,  56.51  ,  73.1   ],
#        [  8.2013,  78.99  ,  62.14  ,  69.31  ,  53.    ,  70.24  ],
#        [  9.2013,  76.77  ,  56.76  ,  65.18  ,  43.87  ,  69.12  ],
#        [ 10.2013,  76.09  ,  50.85  ,  62.13  ,  42.12  ,  68.98  ],
#        [ 11.2013,  76.36  ,  46.43  ,  64.17  ,  43.98  ,  68.58  ],
#        [ 12.2013,  77.16  ,  46.73  ,  65.5   ,  44.66  ,  69.5   ],
#        [  1.2014,  77.5   ,  45.85  ,  66.85  ,  47.73  ,  70.14  ],
#        [  2.2014,  79.03  ,  49.25  ,  68.38  ,  52.31  ,  70.58  ],
# ...

# %%
datas = dado_transposto[:,0]

# %%
precos = dado_transposto[:,1:]

# %%
import matplotlib.pyplot as plt

# %%
datas = np.arange(1,88,1)

# %%
plt.plot(datas,precos[:,0])

# %%
Moscow = precos[:,0]
Kaliningrad = precos[:,1]
Petersburg = precos[:,2]
Krasnodar = precos[:,3]
Ekaterinburg = precos[:,4]

# %%
Moscow_ano1 = Moscow[0:12]
Moscow_ano2 = Moscow[12:24]
Moscow_ano3 = Moscow[24:36]
Moscow_ano4 = Moscow[36:48]
Moscow_ano5 = Moscow[48:60]

# %%
plt.plot(np.arange(1,13,1), Moscow_ano1)
plt.plot(np.arange(1,13,1), Moscow_ano2)
plt.plot(np.arange(1,13,1), Moscow_ano3)
plt.plot(np.arange(1,13,1), Moscow_ano4)
plt.plot(np.arange(1,13,1), Moscow_ano5)
plt.legend(['ano 1', 'ano 2','ano 3','ano 4', 'ano 5'])

# %%
np.array_equal(Moscow_ano1, Moscow_ano2)
# Out:
# False

# %%
np.allclose(Moscow_ano2,Moscow_ano3, 0.01)
# Out:
# False

# %%
plt.plot(datas, Kaliningrad)

# %%
Kaliningrad
# Out:
# array([ 42.67,  44.37,  44.73,  46.75,    nan,  51.59,  57.8 ,  62.14,
#         56.76,  50.85,  46.43,  46.73,  45.85,  49.25,  48.14,  49.18,
#         49.49,  49.83,  49.14,  63.21,  61.2 ,  60.34,  62.2 ,  74.2 ,
#         75.32,  75.92,  72.89,  74.85,  92.19,  99.7 , 102.78,  92.67,
#         90.63,  83.31,  75.5 ,  74.6 ,  76.94,  83.04,  80.74,  80.29,
#         82.82,  86.29,  87.41,  85.1 ,  78.08,  76.06,  69.23,  69.04,
#         64.48,  65.73,  67.2 ,  70.25,  82.59,  92.12, 100.82,  95.23,
#         89.51,  82.84,  82.3 ,  83.76,  84.72,  83.91,  99.14, 101.6 ,
#        113.03, 119.54, 118.09, 107.32,  82.6 ,  77.4 ,  71.77,  71.25,
#         71.35,  73.62,  76.2 ,  74.15,  75.67,  79.2 ,  80.85,  85.33,
#         75.02,  77.95,  78.98,  76.55,  74.89,  70.  ,  81.53])

# %%
sum(np.isnan(Kaliningrad))
# Out:
# 1

# %%
(Kaliningrad[3]+Kaliningrad[5])/2
# Out:
# 49.17

# %%
Kaliningrad[4] = np.mean([Kaliningrad[3],Kaliningrad[5]])

# %%
Kaliningrad
# Out:
# array([ 42.67,  44.37,  44.73,  46.75,  49.17,  51.59,  57.8 ,  62.14,
#         56.76,  50.85,  46.43,  46.73,  45.85,  49.25,  48.14,  49.18,
#         49.49,  49.83,  49.14,  63.21,  61.2 ,  60.34,  62.2 ,  74.2 ,
#         75.32,  75.92,  72.89,  74.85,  92.19,  99.7 , 102.78,  92.67,
#         90.63,  83.31,  75.5 ,  74.6 ,  76.94,  83.04,  80.74,  80.29,
#         82.82,  86.29,  87.41,  85.1 ,  78.08,  76.06,  69.23,  69.04,
#         64.48,  65.73,  67.2 ,  70.25,  82.59,  92.12, 100.82,  95.23,
#         89.51,  82.84,  82.3 ,  83.76,  84.72,  83.91,  99.14, 101.6 ,
#        113.03, 119.54, 118.09, 107.32,  82.6 ,  77.4 ,  71.77,  71.25,
#         71.35,  73.62,  76.2 ,  74.15,  75.67,  79.2 ,  80.85,  85.33,
#         75.02,  77.95,  78.98,  76.55,  74.89,  70.  ,  81.53])

# %%
plt.plot(datas, Kaliningrad)

# %%
np.mean(Moscow)
# Out:
# 98.79781609195402

# %%
np.mean(Kaliningrad)
# Out:
# 74.5506896551724

# %% [markdown]
# # Desafio 2

# %%
citricos = np.loadtxt(url, delimiter=',',skiprows=1, usecols=np.arange(1,6,1))

# %%
diametro = citricos[:,0]
diametro
# Out:
# array([ 2.96,  3.91,  4.42, ..., 15.59, 15.92, 16.45])

# %%
peso = citricos[:,1]
peso
# Out:
# array([ 86.76,  88.05,  95.17, ..., 256.5 , 260.14, 261.51])

# %%
peso_laranja = peso[:5000]
diametro_laranja = diametro[:5000]
peso_laranja, diametro
# Out:
# (array([ 86.76,  88.05,  95.17, ..., 218.07, 230.13, 231.09]),
#  array([ 2.96,  3.91,  4.42, ..., 15.59, 15.92, 16.45]))

# %%
peso_toranja = peso[5000:]
diametro_toranja = diametro[5000:]
peso_toranja, diametro_toranja
# Out:
# (array([126.79, 133.98, 135.56, ..., 256.5 , 260.14, 261.51]),
#  array([ 7.63,  7.69,  7.72, ..., 15.59, 15.92, 16.45]))

# %%
plt.plot(peso_laranja, diametro_laranja)

# %%
plt.plot(peso_toranja, diametro_toranja)

# %% [markdown]
# # ----------------------------

# %%
plt.plot(datas, Moscow)

# %% [markdown]
# y=ax+b a = coeficiente angular e b = coeficiente linear - equação geral da reta

# %%
x = datas
y = 2*x + 80

# %%
plt.plot(datas, Moscow)
plt.plot(x,y)

# %%
np.sqrt(np.sum(np.power(Moscow-y,2)))
# Out:
# 749.2329171225728

# %%
y =0.52*x + 80

# %%
plt.plot(datas, Moscow)
plt.plot(x,y)

# %%
np.sqrt(np.sum(np.power(Moscow-y,2)))
# Out:
# 110.48504740461489

# %%
np.linalg.norm(Moscow-y)
# Out:
# 110.48504740461489

# %% [markdown]
# a = Coeficiente angular
#
# n = numero de elementos
#
# y = moscow
#
# x = datas
#
# Equação do coeficiente angular:
#
# ![image.png](attachment:image.png)

# %%
y = Moscow
x = datas
n = np.size(Moscow)

# %%
(x**2).shape
# Out:
# (87,)

# %%
a = (n*np.sum(x*y) - np.sum(x)*np.sum(y))/(n*np.sum(x**2)-(np.sum(x))**2)
a
# Out:
# 0.43520212145512926

# %% [markdown]
# Coeficiente Linear

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
b = np.mean(y) - a * np.mean(x)

# %%
y = a*x + b

# %%
np.linalg.norm(Moscow - y)
# Out:
# 101.7969539992751

# %%
plt.plot(datas, Moscow)
plt.plot(x,y)
plt.plot(50,50*a+b, '*b')
plt.plot(100,100*a+b, '*b')

# %% [markdown]
# # Desafio 3

# %%
y_laranja = diametro_laranja
x_laranja = peso_laranja
n_laranja = np.size(y_laranja)

a_laranja = (n_laranja*np.sum(x_laranja*y_laranja) - np.sum(x_laranja)*np.sum(y_laranja))/(n_laranja*np.sum(x_laranja**2)-(np.sum(x_laranja))**2)
a_laranja
# Out:
# 0.06748551409607516

# %%
b_laranja = np.mean(y_laranja) - a_laranja * np.mean(x)
b_laranja
# Out:
# 5.505061379772692

# %% [markdown]
# # ----------------------------

# %%
np.random.randint(low=10, high=100, size=100)
# Out:
# array([14, 89, 61, 53, 15, 21, 13, 88, 27, 13, 56, 10, 29, 30, 14, 60, 47,
#        43, 68, 27, 77, 79, 29, 12, 49, 12, 74, 51, 77, 32, 12, 21, 57, 67,
#        95, 80, 86, 76, 10, 17, 73, 23, 38, 97, 73, 85, 66, 54, 96, 31, 38,
#        28, 46, 42, 85, 40, 37, 20, 70, 49, 35, 70, 48, 65, 52, 49, 79, 83,
#        91, 87, 37, 47, 73, 89, 24, 47, 99, 35, 25, 52, 78, 45, 76, 13, 89,
#        42, 92, 52, 10, 39, 81, 82, 69, 98, 93, 90, 69, 67, 41, 83])

# %%
conf_angulares = np.random.uniform(low=0.10, high=0.90,size=100)

# %%
norma = np.array([])

for i in range(100):
   norma = np.append(norma, np.linalg.norm(Moscow-(conf_angulares[i]*x+b)))

# %%
norma
# Out:
# array([241.7996639 , 154.8868453 , 134.14218436, 102.40821956,
#        146.93318557, 122.92576587, 116.32891488, 140.72319783,
#        138.01251068, 102.22927256, 102.14367936, 166.6120143 ,
#        106.01712627, 130.60862249, 109.27804744, 102.81557171,
#        223.02803245, 106.28971475, 193.57524965, 103.10005795,
#        106.44403949, 226.03553473, 110.79961382, 119.72211447,
#        133.90010079, 146.94160294, 102.31425185, 106.83859218,
#        127.21039006, 152.16564653, 147.68101014, 118.95328794,
#        177.21791805, 135.66685876, 223.36274744, 102.04989143,
#        176.93125538, 109.79805472, 225.16106202, 102.27174473,
#        126.23864395, 209.94794732, 122.59915383, 101.98891824,
#        147.69565501, 211.72226926, 102.97063692, 110.56059415,
#        102.38825692, 236.60037776, 119.59705495, 104.18346585,
#        198.73201827, 223.89202109, 219.70772869, 128.32300312,
#        143.86948542, 214.56269998, 105.78869284, 123.44677519,
# ...

# %%
dados = np.column_stack([norma, conf_angulares])

# %%
dados
# Out:
# array([[2.41799664e+02, 8.99341375e-01],
#        [1.54886845e+02, 6.82238428e-01],
#        [1.34142184e+02, 2.50334541e-01],
#        [1.02408220e+02, 4.11559046e-01],
#        [1.46933186e+02, 2.10977916e-01],
#        [1.22925766e+02, 2.89382265e-01],
#        [1.16328915e+02, 5.54345891e-01],
#        [1.40723198e+02, 6.40815232e-01],
#        [1.38012511e+02, 2.37988739e-01],
#        [1.02229273e+02, 4.55076821e-01],
#        [1.02143679e+02, 4.17407026e-01],
#        [1.66612014e+02, 1.56081377e-01],
#        [1.06017126e+02, 3.72532335e-01],
#        [1.30608622e+02, 6.08368317e-01],
#        [1.09278047e+02, 3.51109754e-01],
#        [1.02815572e+02, 4.65753257e-01],
#        [2.23028032e+02, 8.55142212e-01],
#        [1.06289715e+02, 3.70497632e-01],
#        [1.93575250e+02, 7.83628032e-01],
#        [1.03100058e+02, 4.69781165e-01],
#        [1.06444039e+02, 5.01032914e-01],
#        [2.26035535e+02, 8.62282751e-01],
#        [1.10799614e+02, 3.42621694e-01],
# ...
